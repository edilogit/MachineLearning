# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
import seaborn as sns
from sklearn import linear_model
from sklearn import preprocessing
import warnings
warnings.filterwarnings('ignore')
from sklearn.externals import joblib
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# ## Proyecto Final Statistical Learning
# ### Parte 2: Deployment, Inferencia y Seleccion

# %%
## se cargan los modelos elegidos los cuales son Naive-Bayes y SVM penalty=1 kernel=rbf

svm_model = joblib.load('SVM_Penalty_1_kernel_rbf_degree_1_train')
nb_model = joblib.load('NBayes_lr=0.01_reg=0.1_train')

x_test = pd.read_csv('10pruebas.csv')

# %%
### Grafo del arbol de decision
DecisionTree_model = joblib.load('DecTree_sort_true_splitter_random_train')
y_test = DecisionTree_model.predict(x_test)  
tree.plot_tree(DecisionTree_model.fit(x_test,y_test))
# Out:
# [Text(133.92000000000002, 190.26, 'X[7] <= 0.935\nentropy = 0.18\nsamples = 10\nvalue = [1, 9]'),
#  Text(66.96000000000001, 135.9, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(200.88000000000002, 135.9, 'X[0] <= 550.194\nentropy = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(133.92000000000002, 81.53999999999999, 'X[1] <= 21.392\nentropy = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(66.96000000000001, 27.180000000000007, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(200.88000000000002, 27.180000000000007, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(267.84000000000003, 81.53999999999999, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]')]

# %%
def Predecir(model,test_data):       
    y_pred = model.predict(test_data)
    dict = {0: 'Died', 1: 'Survived'}
    result= y_pred[0]
    print(dict.get(result))
    return 1

# %% [markdown]
# ### Resultados individuales con Naive-Bayes

# %%
# Resultados del Naive Bayes
ds1=x_test.iloc[[0]]
Predecir(nb_model,ds1)

ds1=x_test.iloc[[1]]
Predecir(nb_model,ds1)

ds1=x_test.iloc[[2]]
Predecir(nb_model,ds1)

ds1=x_test.iloc[[3]]
Predecir(nb_model,ds1)

ds1=x_test.iloc[[4]]
Predecir(nb_model,ds1)

ds1=x_test.iloc[[5]]
Predecir(nb_model,ds1)

ds1=x_test.iloc[[6]]
Predecir(nb_model,ds1)

ds1=x_test.iloc[[7]]
Predecir(nb_model,ds1)

ds1=x_test.iloc[[8]]
Predecir(nb_model,ds1)

ds1=x_test.iloc[[9]]
Predecir(nb_model,ds1)
# Out:
# Survived
# Survived
# Survived
# Survived
# Survived
# Died
# Died
# Died
# Survived
# Survived
# 1
